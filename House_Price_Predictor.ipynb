# %%
# Import necessary libraries: pandas for data manipulation and numpy for numerical operations.
import pandas as pd
import numpy as np

# %%
# Load the dataset 'Bengaluru_House_Data.csv' into a pandas DataFrame named 'data'.
data=pd.read_csv('/content/Bengaluru_House_Data.csv')

# %%
# Display the first 5 rows of the DataFrame to get a quick overview of the data.
data.head()
# Out:
#               area_type   availability                  location       size  \
# 0  Super built-up  Area         19-Dec  Electronic City Phase II      2 BHK
# 1            Plot  Area  Ready To Move          Chikka Tirupathi  4 Bedroom
# 2        Built-up  Area  Ready To Move               Uttarahalli      3 BHK
# 3  Super built-up  Area  Ready To Move        Lingadheeranahalli      3 BHK
# 4  Super built-up  Area  Ready To Move                  Kothanur      2 BHK
#
#    society total_sqft  bath  balcony   price
# 0  Coomee        1056   2.0      1.0   39.07
# 1  Theanmp       2600   5.0      3.0  120.00
# 2      NaN       1440   2.0      3.0   62.00
# 3  Soiewre       1521   3.0      1.0   95.00
# 4      NaN       1200   2.0      1.0   51.00

# %%
# Display the number of rows and columns in the DataFrame.
data.shape
# Out:
# (13320, 9)

# %%
# Display a concise summary of the DataFrame, including data types and non-null values.
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 13320 entries, 0 to 13319
# Data columns (total 9 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   area_type     13320 non-null  object
#  1   availability  13320 non-null  object
#  2   location      13319 non-null  object
#  3   size          13304 non-null  object
#  4   society       7818 non-null   object
#  5   total_sqft    13320 non-null  object
#  6   bath          13247 non-null  float64
#  7   balcony       12711 non-null  float64
#  8   price         13320 non-null  float64
# dtypes: float64(3), object(6)
# memory usage: 936.7+ KB

# %%
# Iterate through each column and print the value counts for each unique entry, followed by a separator.
for column in data.columns:
  print(data[column].value_counts())
  print("*"*20)
# Out:
# area_type
# Super built-up  Area    8790
# Built-up  Area          2418
# Plot  Area              2025
# Carpet  Area              87
# Name: count, dtype: int64
# ********************
# availability
# Ready To Move    10581
# 18-Dec             307
# 18-May             295
# 18-Apr             271
# 18-Aug             200
#                  ...
# 16-Oct               1
# 17-Jan               1
# 16-Nov               1
# 16-Jan               1
# 14-Jul               1
# Name: count, Length: 81, dtype: int64
# ********************
# location
# Whitefield                         540
# Sarjapur  Road                     399
# Electronic City                    302
# Kanakpura Road                     273
# Thanisandra                        234
#                                   ...
# 3rd Stage Raja Rajeshwari Nagar      1
# Chuchangatta Colony                  1
# Electronic City Phase 1,             1
# Chikbasavanapura                     1
# Abshot Layout                        1
# ...

# %%
# Check for missing values in each column and sum them up.
data.isna().sum()
# Out:
# area_type          0
# availability       0
# location           1
# size              16
# society         5502
# total_sqft         0
# bath              73
# balcony          609
# price              0
# dtype: int64

# %%
# Drop irrelevant columns ('area_type', 'availability', 'society', 'balcony') from the DataFrame.
data.drop(columns=['area_type','availability','society','balcony'], inplace=True)

# %%
# Display descriptive statistics (count, mean, std, min, max, quartiles) for numerical columns.
data.describe()
# Out:
#                bath         price
# count  13247.000000  13320.000000
# mean       2.692610    112.565627
# std        1.341458    148.971674
# min        1.000000      8.000000
# 25%        2.000000     50.000000
# 50%        2.000000     72.000000
# 75%        3.000000    120.000000
# max       40.000000   3600.000000

# %%
# Display an updated concise summary of the DataFrame after dropping columns.
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 13320 entries, 0 to 13319
# Data columns (total 5 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   location    13319 non-null  object
#  1   size        13304 non-null  object
#  2   total_sqft  13320 non-null  object
#  3   bath        13247 non-null  float64
#  4   price       13320 non-null  float64
# dtypes: float64(2), object(3)
# memory usage: 520.4+ KB

# %%
# Display the value counts for the 'location' column.
data['location'].value_counts()
# Out:
# location
# Whitefield                         540
# Sarjapur  Road                     399
# Electronic City                    302
# Kanakpura Road                     273
# Thanisandra                        234
#                                   ...
# 3rd Stage Raja Rajeshwari Nagar      1
# Chuchangatta Colony                  1
# Electronic City Phase 1,             1
# Chikbasavanapura                     1
# Abshot Layout                        1
# Name: count, Length: 1305, dtype: int64

# %%
# Fill any missing values in the 'location' column with 'Sarjapur Road'.
data['location']= data['location'].fillna('Sarjapur Road')

# %%
# Display the value counts for the 'size' column.
data['size'].value_counts()
# Out:
# size
# 2 BHK         5199
# 3 BHK         4310
# 4 Bedroom      826
# 4 BHK          591
# 3 Bedroom      547
# 1 BHK          538
# 2 Bedroom      329
# 5 Bedroom      297
# 6 Bedroom      191
# 1 Bedroom      105
# 8 Bedroom       84
# 7 Bedroom       83
# 5 BHK           59
# 9 Bedroom       46
# 6 BHK           30
# 7 BHK           17
# 1 RK            13
# 10 Bedroom      12
# 9 BHK            8
# 8 BHK            5
# 11 BHK           2
# 10 BHK           2
# 11 Bedroom       2
# 27 BHK           1
# 19 BHK           1
# 43 Bedroom       1
# 16 BHK           1
# 14 BHK           1
# 12 Bedroom       1
# 13 BHK           1
# 18 Bedroom       1
# Name: count, dtype: int64

# %%
# Fill any missing values in the 'size' column with '2BHK'.
data['size']=data['size'].fillna('2BHK')

# %%
# Fill any missing values in the 'bath' (number of bathrooms) column with the median value of the column.
data['bath']=data['bath'].fillna(data['bath'].median())

# %%
# Display an updated concise summary of the DataFrame after handling missing values.
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 13320 entries, 0 to 13319
# Data columns (total 5 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   location    13320 non-null  object
#  1   size        13320 non-null  object
#  2   total_sqft  13320 non-null  object
#  3   bath        13320 non-null  float64
#  4   price       13320 non-null  float64
# dtypes: float64(2), object(3)
# memory usage: 520.4+ KB

# %%
# Extract the numerical part from the 'size' column to create a new 'bhk' (BHK - Bedroom, Hall, Kitchen) column, and convert it to integer type.
data['bhk']=data['size'].str.extract('(\d+)').astype(int)
# Out:
# <>:2: SyntaxWarning: invalid escape sequence '\d'
# <>:2: SyntaxWarning: invalid escape sequence '\d'
# /tmp/ipykernel_618/969694795.py:2: SyntaxWarning: invalid escape sequence '\d'
#   data['bhk']=data['size'].str.extract('(\d+)').astype(int)

# %%
# Display rows where the 'bhk' count is unusually high (greater than 20) to identify potential data entry errors or outliers.
data[data.bhk > 20]
# Out:
#                        location        size total_sqft  bath  price  bhk
# 1718  2Electronic City Phase II      27 BHK       8000  27.0  230.0   27
# 4684                Munnekollal  43 Bedroom       2400  40.0  660.0   43

# %%
# Display all unique values in the 'total_sqft' column to understand its data format.
data['total_sqft'].unique()
# Out:
# array(['1056', '2600', '1440', ..., '1133 - 1384', '774', '4689'],
#       dtype=object)

# %%
# Define a function to convert 'total_sqft' values that are ranges (e.g., '1000-1200') into their average, and convert other values to float.
def convertRange(x):
  temp=x.split('-')
  if len(temp) == 2:
    return (float(temp[0]) + float(temp[1]))/2
  try:
    return float(x)
  except:
    return None

# %%
# Apply the 'convertRange' function to the 'total_sqft' column to clean and standardize the values.
data['total_sqft']=data['total_sqft'].apply(convertRange)

# %%
# Display the first few rows of the DataFrame again to see the changes after cleaning 'total_sqft'.
data.head()
# Out:
#                    location       size  total_sqft  bath   price  bhk
# 0  Electronic City Phase II      2 BHK      1056.0   2.0   39.07    2
# 1          Chikka Tirupathi  4 Bedroom      2600.0   5.0  120.00    4
# 2               Uttarahalli      3 BHK      1440.0   2.0   62.00    3
# 3        Lingadheeranahalli      3 BHK      1521.0   3.0   95.00    3
# 4                  Kothanur      2 BHK      1200.0   2.0   51.00    2

# %%
# Add a markdown comment to indicate the next step is to calculate 'Price per square feet'.

# %%
# Calculate 'price_per_sqft' by dividing the price (in lakhs, so multiplied by 100000) by 'total_sqft'.
data['price_per_sqft']=data['price']*100000/data['total_sqft']

# %%
# Display the calculated 'price_per_sqft' column.
data['price_per_sqft']
# Out:
# 0         3699.810606
# 1         4615.384615
# 2         4305.555556
# 3         6245.890861
# 4         4250.000000
#              ...
# 13315     6689.834926
# 13316    11111.111111
# 13317     5258.545136
# 13318    10407.336319
# 13319     3090.909091
# Name: price_per_sqft, Length: 13320, dtype: float64

# %%
# Display descriptive statistics for the DataFrame, including the newly created 'price_per_sqft' column.
data.describe()
# Out:
#          total_sqft          bath         price           bhk  price_per_sqft
# count  13274.000000  13320.000000  13320.000000  13320.000000    1.327400e+04
# mean    1559.626694      2.688814    112.565627      2.802778    7.907501e+03
# std     1238.405258      1.338754    148.971674      1.294496    1.064296e+05
# min        1.000000      1.000000      8.000000      1.000000    2.678298e+02
# 25%     1100.000000      2.000000     50.000000      2.000000    4.266865e+03
# 50%     1276.000000      2.000000     72.000000      3.000000    5.434306e+03
# 75%     1680.000000      3.000000    120.000000      3.000000    7.311746e+03
# max    52272.000000     40.000000   3600.000000     43.000000    1.200000e+07

# %%
# Display the value counts for the 'location' column again to assess its distribution.
data['location'].value_counts()
# Out:
# location
# Whitefield                  540
# Sarjapur  Road              399
# Electronic City             302
# Kanakpura Road              273
# Thanisandra                 234
#                            ...
# Mango Garden Layout           1
# Milk Colony                   1
# Basnashankari,6th stage,      1
# Near ullas theater            1
# N R Layout                    1
# Name: count, Length: 1306, dtype: int64

# %%
# Remove leading/trailing whitespace from 'location' names and then calculate the value counts for each location.
data['location']=data['location'].apply(lambda x: x.strip())
location_count= data['location'].value_counts()

# %%
# Identify locations that appear 10 or fewer times, which will be grouped into 'other'.
location_count_less_10 = location_count[location_count<=10]
location_count_less_10
# Out:
# location
# 1st Block Koramangala     10
# Dairy Circle              10
# Nagadevanahalli           10
# Sadashiva Nagar           10
# Naganathapura             10
#                           ..
# Xavier Layout              1
# Ramanagara Channapatna     1
# Maheswari Nagar            1
# Hsr layout sector3         1
# Thyagraj Nagar             1
# Name: count, Length: 1054, dtype: int64

# %%
# Replace infrequent locations (those in 'location_count_less_10') with 'other' to reduce dimensionality.
data['location']=data['location'].apply(lambda x:'other' if x in location_count_less_10 else x)

# %%
# Display the updated value counts for the 'location' column after grouping infrequent locations.
data['location'].value_counts()
# Out:
# location
# other                        2886
# Whitefield                    541
# Sarjapur  Road                399
# Electronic City               304
# Kanakpura Road                273
#                              ...
# Tindlu                         11
# Marsur                         11
# 2nd Phase Judicial Layout      11
# Thyagaraja Nagar               11
# HAL 2nd Stage                  11
# Name: count, Length: 242, dtype: int64

# %%
# Add a markdown comment to indicate the next steps involve outlier detection and removal.
#Outliers  Detection and removal

# %%
# Display descriptive statistics for the DataFrame again before outlier removal.
data.describe()
# Out:
#          total_sqft          bath         price           bhk  price_per_sqft
# count  13274.000000  13320.000000  13320.000000  13320.000000    1.327400e+04
# mean    1559.626694      2.688814    112.565627      2.802778    7.907501e+03
# std     1238.405258      1.338754    148.971674      1.294496    1.064296e+05
# min        1.000000      1.000000      8.000000      1.000000    2.678298e+02
# 25%     1100.000000      2.000000     50.000000      2.000000    4.266865e+03
# 50%     1276.000000      2.000000     72.000000      3.000000    5.434306e+03
# 75%     1680.000000      3.000000    120.000000      3.000000    7.311746e+03
# max    52272.000000     40.000000   3600.000000     43.000000    1.200000e+07

# %%
# Calculate and display descriptive statistics for 'total_sqft' per 'bhk', which is used to identify outliers.
(data['total_sqft']/data['bhk']).describe()
# Out:
# count    13274.000000
# mean       575.074878
# std        388.205175
# min          0.250000
# 25%        473.333333
# 50%        552.500000
# 75%        625.000000
# max      26136.000000
# dtype: float64

# %%
# Filter out rows where the 'total_sqft' per 'bhk' is less than 300, as these are considered outliers.
data=data[((data['total_sqft']/data['bhk']) >= 300)]
data.describe()
# Out:
#          total_sqft          bath         price           bhk  price_per_sqft
# count  12530.000000  12530.000000  12530.000000  12530.000000    12530.000000
# mean    1594.564544      2.559537    111.382401      2.650838     6303.979357
# std     1261.271296      1.077938    152.077329      0.976678     4162.237981
# min      300.000000      1.000000      8.440000      1.000000      267.829813
# 25%     1116.000000      2.000000     49.000000      2.000000     4210.526316
# 50%     1300.000000      2.000000     70.000000      3.000000     5294.117647
# 75%     1700.000000      3.000000    115.000000      3.000000     6916.666667
# max    52272.000000     16.000000   3600.000000     16.000000   176470.588235

# %%
# Display the shape of the DataFrame after removing outliers based on 'total_sqft' per 'bhk'.
data.shape
# Out:
# (12530, 7)

# %%
# Display descriptive statistics specifically for the 'price_per_sqft' column.
data.price_per_sqft.describe()
# Out:
# count     12530.000000
# mean       6303.979357
# std        4162.237981
# min         267.829813
# 25%        4210.526316
# 50%        5294.117647
# 75%        6916.666667
# max      176470.588235
# Name: price_per_sqft, dtype: float64

# %%
# Define a function to remove outliers based on 'price_per_sqft' within each location, using the mean and standard deviation.
def remove_outliers_sqft(df):
  df_output = pd.DataFrame()
  for key,subdf in df.groupby('location'):
    m = np.mean(subdf.price_per_sqft)
    st = np.std(subdf.price_per_sqft)
    gen_df = subdf[(subdf.price_per_sqft > (m-st)) & (subdf.price_per_sqft <= (m+st))]
    df_output = pd.concat([df_output,gen_df],ignore_index = True)
  return df_output
data = remove_outliers_sqft(data)
data.describe()
# Out:
#          total_sqft          bath         price           bhk  price_per_sqft
# count  10301.000000  10301.000000  10301.000000  10301.000000    10301.000000
# mean    1508.440608      2.471702     91.286372      2.574896     5659.062876
# std      880.694214      0.979449     86.342786      0.897649     2265.774749
# min      300.000000      1.000000     10.000000      1.000000     1250.000000
# 25%     1110.000000      2.000000     49.000000      2.000000     4244.897959
# 50%     1286.000000      2.000000     67.000000      2.000000     5175.600739
# 75%     1650.000000      3.000000    100.000000      3.000000     6428.571429
# max    30400.000000     16.000000   2200.000000     16.000000    24509.803922

# %%
# Define a function to remove BHK outliers. This function iterates through locations and BHK configurations, removing properties where the price per sqft is significantly lower than that of a lower BHK configuration in the same location.
def bhk_outlier_remover(df):
  exclude_indices = np.array([])
  for location, location_df in df.groupby('location'):
    bhk_stats = {}
    for bhk, bhk_df in location_df.groupby('bhk'):
      bhk_stats[bhk] = {
          'mean': np.mean(bhk_df.price_per_sqft),
          'std': np.std(bhk_df.price_per_sqft),
          'count': bhk_df.shape[0]
      }

      for bhk, bhk_df in location_df.groupby('bhk'):
        stats = bhk_stats.get(bhk-1)
        if stats and stats['count']>5:
          exclude_indices = np.append(exclude_indices, bhk_df[bhk_df.price_per_sqft<(stats['mean'])].index.values)
  return df.drop(exclude_indices,axis='index')

# %%
# Apply the 'bhk_outlier_remover' function to the DataFrame to remove BHK-based outliers.
data=bhk_outlier_remover(data)

# %%
# Display the shape of the DataFrame after all outlier removal steps.
data.shape
# Out:
# (7361, 7)

# %%
# Display the entire DataFrame after cleaning and outlier removal.
data
# Out:
#                   location       size  total_sqft  bath  price  bhk  \
# 0      1st Block Jayanagar      4 BHK      2850.0   4.0  428.0    4
# 1      1st Block Jayanagar      3 BHK      1630.0   3.0  194.0    3
# 2      1st Block Jayanagar      3 BHK      1875.0   2.0  235.0    3
# 3      1st Block Jayanagar      3 BHK      1200.0   2.0  130.0    3
# 4      1st Block Jayanagar      2 BHK      1235.0   2.0  148.0    2
# ...                    ...        ...         ...   ...    ...  ...
# 10292                other      2 BHK      1200.0   2.0   70.0    2
# 10293                other      1 BHK      1800.0   1.0  200.0    1
# 10296                other      2 BHK      1353.0   2.0  110.0    2
# 10297                other  1 Bedroom       812.0   1.0   26.0    1
# 10300                other      4 BHK      3600.0   5.0  400.0    4
#
#        price_per_sqft
# 0        15017.543860
# 1        11901.840491
# 2        12533.333333
# 3        10833.333333
# 4        11983.805668
# ...

# %%
# Drop the 'size' and 'price_per_sqft' columns as they are no longer needed for model training.
data.drop(columns=['size','price_per_sqft'],inplace=True)

# %%
# Add a markdown comment to indicate that the data is now cleaned.
#Cleaned Data

# %%
# Display the first few rows of the final cleaned DataFrame.
data.head()
# Out:
#               location  total_sqft  bath  price  bhk
# 0  1st Block Jayanagar      2850.0   4.0  428.0    4
# 1  1st Block Jayanagar      1630.0   3.0  194.0    3
# 2  1st Block Jayanagar      1875.0   2.0  235.0    3
# 3  1st Block Jayanagar      1200.0   2.0  130.0    3
# 4  1st Block Jayanagar      1235.0   2.0  148.0    2

# %%
# Save the cleaned DataFrame to a new CSV file named 'Cleaned_data.csv'.
data.to_csv("Cleaned_data.csv")

# %%
# Separate the features (X) from the target variable (y, which is 'price').
X=data.drop(columns=['price'])
y=data['price']

# %%
from sklearn.model_selection import train_test_split
from sklearn.linear_model import LinearRegression,Lasso,Ridge
from sklearn.preprocessing import OneHotEncoder, StandardScaler
from sklearn.compose import make_column_transformer
from sklearn.pipeline import make_pipeline
from sklearn.metrics import r2_score

# %%
# Split the data into training and testing sets (80% training, 20% testing) for model evaluation.
X_train,X_test,y_train,y_test = train_test_split(X,y,test_size=0.2,random_state=0)

# %%
# Print the shapes of the training and testing feature sets to verify the split.
print(X_train.shape)
print(X_test.shape)
# Out:
# (5888, 4)
# (1473, 4)

# %%
# Add a markdown comment to indicate the application of Linear Regression.
#Applying Linear Regression

# %%
# Create a ColumnTransformer to apply OneHotEncoder to the 'location' column, and leave other columns as is.
column_trans = make_column_transformer((OneHotEncoder(sparse_output=False),['location']),remainder='passthrough')

# %%
# Initialize a StandardScaler to scale numerical features.
scaler = StandardScaler()

# %%
# Empty cell, could be used for additional setup or comments.

# %%
# Empty cell, could be used for additional setup or comments.

# %%
# Initialize a Linear Regression model.
lr = LinearRegression()

# %%
# Create a pipeline that first applies the column transformations (OneHotEncoder), then scales the data, and finally applies Linear Regression.
pipe = make_pipeline(column_trans,scaler,lr)

# %%
# Fit the Linear Regression pipeline to the training data.
pipe.fit(X_train,y_train)
# Out:
# /usr/local/lib/python3.12/dist-packages/sklearn/compose/_column_transformer.py:1667: FutureWarning:
# The format of the columns of the 'remainder' transformer in ColumnTransformer.transformers_ will change in version 1.7 to match the format of the other transformers.
# At the moment the remainder columns are stored as indices (of type int). With the same ColumnTransformer configuration, in the future they will be stored as column names (of type str).
# To use the new behavior now and suppress this warning, use ColumnTransformer(force_int_remainder_cols=False).
#
#   warnings.warn(
# Pipeline(steps=[('columntransformer',
#                  ColumnTransformer(remainder='passthrough',
#                                    transformers=[('onehotencoder',
#                                                   OneHotEncoder(sparse_output=False),
#                                                   ['location'])])),
#                 ('standardscaler', StandardScaler()),
# ...

# %%
# Use the trained Linear Regression pipeline to make predictions on the test set.
y_pred_lr = pipe.predict(X_test)

# %%
# Calculate and display the R-squared score for the Linear Regression model, comparing actual vs. predicted values.
r2_score(y_test,y_pred_lr)
# Out:
# 0.8233783132019381

# %%
# Add a markdown comment to indicate the next step is to apply Lasso Regression.
# Applying Lasso

# %%
# Initialize a Lasso Regression model.
lasso = Lasso()

# %%
# Create a new pipeline for Lasso Regression, incorporating column transformations, scaling, and the Lasso model.
pipe = make_pipeline(column_trans,scaler,lasso)

# %%
# Fit the Lasso Regression pipeline to the training data.
pipe.fit(X_train,y_train)
# Out:
# /usr/local/lib/python3.12/dist-packages/sklearn/compose/_column_transformer.py:1667: FutureWarning:
# The format of the columns of the 'remainder' transformer in ColumnTransformer.transformers_ will change in version 1.7 to match the format of the other transformers.
# At the moment the remainder columns are stored as indices (of type int). With the same ColumnTransformer configuration, in the future they will be stored as column names (of type str).
# To use the new behavior now and suppress this warning, use ColumnTransformer(force_int_remainder_cols=False).
#
#   warnings.warn(
# Pipeline(steps=[('columntransformer',
#                  ColumnTransformer(remainder='passthrough',
#                                    transformers=[('onehotencoder',
#                                                   OneHotEncoder(sparse_output=False),
#                                                   ['location'])])),
#                 ('standardscaler', StandardScaler()), ('lasso', Lasso())])

# %%
# Use the trained Lasso Regression pipeline to make predictions on the test set and calculate its R-squared score.
y_pred_lasso = pipe.predict(X_test)
r2_score(y_test,y_pred_lasso)
# Out:
# 0.8128285650772719

# %%
# Add a markdown comment to indicate the next step is to apply Ridge Regression.
# Applying Ridge

# %%
# Initialize a Ridge Regression model.
ridge = Ridge()

# %%
pipe = make_pipeline(column_trans,scaler,ridge)

# %%
pipe.fit(X_train,y_train)
# Out:
# /usr/local/lib/python3.12/dist-packages/sklearn/compose/_column_transformer.py:1667: FutureWarning:
# The format of the columns of the 'remainder' transformer in ColumnTransformer.transformers_ will change in version 1.7 to match the format of the other transformers.
# At the moment the remainder columns are stored as indices (of type int). With the same ColumnTransformer configuration, in the future they will be stored as column names (of type str).
# To use the new behavior now and suppress this warning, use ColumnTransformer(force_int_remainder_cols=False).
#
#   warnings.warn(
# Pipeline(steps=[('columntransformer',
#                  ColumnTransformer(remainder='passthrough',
#                                    transformers=[('onehotencoder',
#                                                   OneHotEncoder(sparse_output=False),
#                                                   ['location'])])),
#                 ('standardscaler', StandardScaler()), ('ridge', Ridge())])

# %%
# Use the trained Ridge Regression pipeline to make predictions on the test set and calculate its R-squared score.
y_pred_ridge = pipe.predict(X_test)
r2_score(y_test,y_pred_ridge)
# Out:
# 0.8234146633312639

# %%
# Print and compare the R-squared scores for all three models: Linear Regression (No Regularization), Lasso, and Ridge.
print("No Regularization: ", r2_score(y_test,y_pred_lr))
print("Lasso: ", r2_score(y_test,y_pred_lasso))
print("Ridge: ", r2_score(y_test,y_pred_ridge))
# Out:
# No Regularization:  0.8233783132019381
# Lasso:  0.8128285650772719
# Ridge:  0.8234146633312639

# %%
# Import the pickle library, which is used for serializing and de-serializing Python objects.
import pickle

# %%
# Save the trained Ridge Regression pipeline to a file named 'RidgeModel.pkl' for future use.
pickle.dump(pipe,open('RidgeModel.pkl','wb'))

# %%
# Empty cell, could be used for additional setup or comments.

# %%
import joblib

# Save the trained Ridge Regression pipeline
joblib.dump(pipe, "RidgeModel_new.joblib")
print("Saved successfully!")
# Out:
# Saved successfully!

# %%
# Re-defining and saving the Ridge Regression pipeline correctly

from sklearn.compose import make_column_transformer
from sklearn.preprocessing import OneHotEncoder, StandardScaler
from sklearn.linear_model import Ridge
from sklearn.pipeline import make_pipeline
import joblib

# 1. Define column_trans (OneHotEncoder for 'location')
column_trans = make_column_transformer((OneHotEncoder(sparse_output=False),['location']),remainder='passthrough')

# 2. Initialize scaler
scaler = StandardScaler()

# 3. Initialize Ridge model
ridge = Ridge()

# 4. Create the pipeline
pipe = make_pipeline(column_trans,scaler,ridge)

# 5. Fit the pipeline to the training data
pipe.fit(X_train,y_train)

# 6. Save the trained Ridge Regression pipeline
joblib.dump(pipe, "RidgeModel_new.joblib")
print("RidgeModel_new.joblib saved successfully!")
# Out:
# RidgeModel_new.joblib saved successfully!

# %% [markdown]
# ### Streamlit Application for House Price Prediction
#
# Streamlit is an open-source Python library that makes it easy to create and share beautiful, custom web apps for machine learning and data science. In this project, you can use Streamlit to build an interactive interface where users can input details about a house and get a predicted price based on your trained Ridge Regression model.
#
# To run a Streamlit app, you would typically save the following code in a `.py` file (e.g., `app.py`) and then execute it from your terminal using `streamlit run app.py`.

# %%
# %%writefile bengaluru-house-price-predictor/app.py
import streamlit as st
import joblib
import pandas as pd

# Load the trained model
try:
    model = joblib.load('bengaluru-house-price-predictor/model.pkl')
except FileNotFoundError:
    st.error("Model file 'bengaluru-house-price-predictor/model.pkl' not found. Please ensure it has been saved correctly.")
    st.stop()

st.title('Bengaluru House Price Prediction')

# Input fields for features
st.header('Enter House Details')

location = st.selectbox('Location', ['other', 'Whitefield', 'Sarjapur  Road', 'Electronic City', 'Kanakpura Road', 'Thanisandra', 'Yelahanka', 'Uttarahalli', 'Hebbal', 'Raja Rajeshwari Nagar', 'Marathahalli', 'Hennur Road', 'Banashankari', 'Haralur Road', 'Electronic City Phase II', 'Hosur Road', 'Old Airport Road', 'Kothanur', 'Rustam Bagh', 'Kadugodi', '7th Phase JP Nagar', 'Kaggadasapura', 'Chandapura', 'Kengeri', 'Domlur', 'Yeshwanthpur', 'Sarjapur', 'Kasavanhalli', 'Begur Road', 'Ramamurthy Nagar', 'Malleshwaram', 'Varthur', 'Bommasandra', 'BTM 2nd Stage', 'Tin Factory', 'Bellandur', 'Panathur', 'JP Nagar', 'Cunningham Road', 'HSR Layout', 'Devanahalli', 'Gottigere', 'Mysore Road', 'KR Puram', 'Frazer Town', 'Anekal', 'Jigani', 'Attibele', 'Lakshminarayana Pura', 'Hoodi', 'Koramangala', 'Hosa Road', 'Kudlu Gate', 'Akshaya Nagar', 'Binny Pete', 'Thigalarapalya', 'Talaghattapura', 'Vidyaranyapura', 'Subramanyapura', 'Old Madras Road', 'Bommanahalli', 'Balagere', 'Kenchenahalli', 'Green Glen Layout', 'EPIP Zone', 'Rajaji Nagar', 'Kodichikkanahalli', 'Kaval Byrasandra', 'Konanakunte', 'Kothannur', 'TC Palaya', 'Kasturi Nagar', 'Ambalipura', 'Manyata Tech Park', 'Bhoganhalli', 'Yelahanka New Town', 'Jalahalli', 'Magadi Road', 'Singasandra', 'Budigere', 'Kengeri Satellite Town', 'Brookefield', 'Bannerghatta Road', 'Kaikondrahalli', 'Harlur', 'Hulimavu', 'Hoskote', 'HBR Layout', 'Doddathoguru', 'Somasundara Palya', 'Kumbalgodu', 'Horamavu Agara', 'Nagavara', 'Horamavu', 'Whitefield,', 'Ambedkar Nagar', 'Battarahalli', 'Kannamangala', 'Tumkur Road', 'Kengeri Hobli', 'Dodda Nekkundi', 'Ardendale', 'Channasandra', 'Vasanthapura', 'Benson Town', 'Hegde Nagar', 'Thurahalli', 'Varthur Road', 'Kathriguppe', 'Halanayakanahalli', 'Hegganahalli', 'Gunjur', 'Singena Agrahara', 'Electronic City Phase I', 'Yelahanka, Jakkur', 'Byatarayanapura', 'Margondanahalli', 'Arekere', 'Seegehalli', 'Kanakapura', 'Dasanapura', 'Kengeri Main Road', 'Ramakrishnappa Layout', 'Bisuvanahalli', 'Jakkur', 'Kundalahalli', 'Bikasipura', 'Sahakara Nagar', 'Rayasandra', 'Kodigehalli', 'Begur', 'Banashankari Stage III', 'Choodasandra', 'Hadosiddapura', 'JP Nagar, Phase 1', 'Subramanya Pura', 'Jalahalli West', 'Doddenakundi Industrial Estate', 'Jayamahal', 'Gollahalli', 'Carmelaram', 'Kudlu', 'K Narayanapura', 'Borewell Road', 'Kanakapura Road,', 'Chikkalasandra', 'Talakaveri Layout', 'Jakkur Plantation', 'Chikkabanavar', 'Hoodi Residential Locality', 'Kothanur,', 'Kodihalli', 'Vittasandra', 'HSR Layout Sector 2', 'Nagasandra', 'Varthur, Whitefield', 'Kalyan Nagar', 'Balagere Road', 'Chikkaballapur', 'Hongasandra', 'Kogilu', 'Old Town', 'Gubbalala', 'Pattandur Agrahara', 'BTM Layout', 'Koramangala,', 'Nallurhalli', 'Konappana Agrahara', 'Panathur Road', 'Banashankari Stage II', 'Dodsworth Layout', 'ITPL', 'Anjanapura', 'Varanasi', 'Kannahalli', 'Hennur Bande', 'Abbigere', 'Sarjapur Road,', 'Sompura', 'Kengeri Satellite Town,', 'Rachenahalli', 'Banashankari Stage VI', 'Harlur Road', 'Ananth Nagar', 'R.T. Nagar', 'Hulimavu,', 'CV Raman Nagar', 'Tindlu', 'Marsur', '2nd Phase Judicial Layout', 'Thyagaraja Nagar', 'HAL 2nd Stage'])
total_sqft = st.number_input('Total Square Feet', min_value=300.0, max_value=50000.0, value=1200.0)
bath = st.slider('Number of Bathrooms', min_value=1, max_value=16, value=2)
bhk = st.slider('Number of BHK', min_value=1, max_value=16, value=2)

if st.button('Predict Price'):
    # Create a DataFrame for prediction
    input_data = pd.DataFrame([{
        'location': location,
        'total_sqft': total_sqft,
        'bath': float(bath),
        'bhk': float(bhk)
    }])

    # Make prediction
    prediction = model.predict(input_data)[0]
    st.success(f'Predicted House Price: ₹ {prediction:.2f} Lakhs')
# Out:
# Writing bengaluru-house-price-predictor/app.py

# %%
# !pip install streamlit

import streamlit as st
import joblib
import pandas as pd

# Load the trained model
# Assuming 'RidgeModel_new.joblib' was successfully saved from the pipeline object
# You might need to re-run the cell where the 'pipe' was defined and saved if it wasn't successful.
try:
    model = joblib.load('RidgeModel_new.joblib')
except FileNotFoundError:
    st.error("Model file 'RidgeModel_new.joblib' not found. Please ensure it has been saved correctly.")
    st.stop()

st.title('Bengaluru House Price Prediction')

# Input fields for features
st.header('Enter House Details')

location = st.selectbox('Location', ['other', 'Whitefield', 'Sarjapur  Road', 'Electronic City', 'Kanakpura Road', 'Thanisandra', 'Yelahanka', 'Uttarahalli', 'Hebbal', 'Raja Rajeshwari Nagar', 'Marathahalli', 'Hennur Road', 'Banashankari', 'Haralur Road', 'Electronic City Phase II', 'Hosur Road', 'Old Airport Road', 'Kothanur', 'Rustam Bagh', 'Kadugodi', '7th Phase JP Nagar', 'Kaggadasapura', 'Chandapura', 'Kengeri', 'Domlur', 'Yeshwanthpur', 'Sarjapur', 'Kasavanhalli', 'Begur Road', 'Ramamurthy Nagar', 'Malleshwaram', 'Varthur', 'Bommasandra', 'BTM 2nd Stage', 'Tin Factory', 'Bellandur', 'Panathur', 'JP Nagar', 'Cunningham Road', 'HSR Layout', 'Devanahalli', 'Gottigere', 'Mysore Road', 'KR Puram', 'Frazer Town', 'Anekal', 'Jigani', 'Attibele', 'Lakshminarayana Pura', 'Hoodi', 'Koramangala', 'Hosa Road', 'Kudlu Gate', 'Akshaya Nagar', 'Binny Pete', 'Thigalarapalya', 'Talaghattapura', 'Vidyaranyapura', 'Subramanyapura', 'Old Madras Road', 'Bommanahalli', 'Balagere', 'Kenchenahalli', 'Green Glen Layout', 'EPIP Zone', 'Rajaji Nagar', 'Kodichikkanahalli', 'Kaval Byrasandra', 'Konanakunte', 'Kothannur', 'TC Palaya', 'Kasturi Nagar', 'Ambalipura', 'Manyata Tech Park', 'Bhoganhalli', 'Yelahanka New Town', 'Jalahalli', 'Magadi Road', 'Singasandra', 'Budigere', 'Kengeri Satellite Town', 'Brookefield', 'Bannerghatta Road', 'Kaikondrahalli', 'Harlur', 'Hulimavu', 'Hoskote', 'HBR Layout', 'Doddathoguru', 'Somasundara Palya', 'Kumbalgodu', 'Horamavu Agara', 'Nagavara', 'Horamavu', 'Whitefield,', 'Ambedkar Nagar', 'Battarahalli', 'Kannamangala', 'Tumkur Road', 'Kengeri Hobli', 'Dodda Nekkundi', 'Ardendale', 'Channasandra', 'Vasanthapura', 'Benson Town', 'Hegde Nagar', 'Thurahalli', 'Varthur Road', 'Kathriguppe', 'Halanayakanahalli', 'Hegganahalli', 'Gunjur', 'Singena Agrahara', 'Electronic City Phase I', 'Yelahanka, Jakkur', 'Byatarayanapura', 'Margondanahalli', 'Arekere', 'Seegehalli', 'Kanakapura', 'Dasanapura', 'Kengeri Main Road', 'Ramakrishnappa Layout', 'Bisuvanahalli', 'Jakkur', 'Kundalahalli', 'Bikasipura', 'Sahakara Nagar', 'Rayasandra', 'Kodigehalli', 'Begur', 'Banashankari Stage III', 'Choodasandra', 'Hadosiddapura', 'JP Nagar, Phase 1', 'Subramanya Pura', 'Jalahalli West', 'Doddenakundi Industrial Estate', 'Jayamahal', 'Gollahalli', 'Carmelaram', 'Kudlu', 'K Narayanapura', 'Borewell Road', 'Kanakapura Road,', 'Chikkalasandra', 'Talakaveri Layout', 'Jakkur Plantation', 'Chikkabanavar', 'Hoodi Residential Locality', 'Kothanur,', 'Kodihalli', 'Vittasandra', 'HSR Layout Sector 2', 'Nagasandra', 'Varthur, Whitefield', 'Kalyan Nagar', 'Balagere Road', 'Chikkaballapur', 'Hongasandra', 'Kogilu', 'Old Town', 'Gubbalala', 'Pattandur Agrahara', 'BTM Layout', 'Koramangala,', 'Nallurhalli', 'Konappana Agrahara', 'Panathur Road', 'Banashankari Stage II', 'Dodsworth Layout', 'ITPL', 'Anjanapura', 'Varanasi', 'Kannahalli', 'Hennur Bande', 'Abbigere', 'Sarjapur Road,', 'Sompura', 'Kengeri Satellite Town,', 'Rachenahalli', 'Banashankari Stage VI', 'Harlur Road', 'Ananth Nagar', 'R.T. Nagar', 'Hulimavu,', 'CV Raman Nagar', 'Tindlu', 'Marsur', '2nd Phase Judicial Layout', 'Thyagaraja Nagar', 'HAL 2nd Stage'])
total_sqft = st.number_input('Total Square Feet', min_value=300.0, max_value=50000.0, value=1200.0)
bath = st.slider('Number of Bathrooms', min_value=1, max_value=16, value=2)
bhk = st.slider('Number of BHK', min_value=1, max_value=16, value=2)

if st.button('Predict Price'):
    # Create a DataFrame for prediction
    input_data = pd.DataFrame([{
        'location': location,
        'total_sqft': total_sqft,
        'bath': float(bath),
        'bhk': float(bhk)
    }])

    # Make prediction
    prediction = model.predict(input_data)[0]
    st.success(f'Predicted House Price: ₹ {prediction:.2f} Lakhs')

# To run this Streamlit app:
# 1. Save the code above to a file named `app.py`.
# 2. Open your terminal or command prompt.
# 3. Navigate to the directory where you saved `app.py`.
# 4. Run the command: `streamlit run app.py`
# 5. Your web browser will open with the Streamlit application.
# Out:
# ...
# 2026-06-17 13:06:24.116 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2026-06-17 13:06:24.117 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2026-06-17 13:06:24.118 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2026-06-17 13:06:24.119 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2026-06-17 13:06:24.120 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2026-06-17 13:06:24.121 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2026-06-17 13:06:24.122 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# ...

# %%
# !pip install streamlit pyngrok joblib scikit-learn pandas numpy

# %%
# !streamlit run app.py &>/content/logs.txt &

# %%
from pyngrok import ngrok

# Replace 'YOUR_AUTHTOKEN' with your actual ngrok authtoken
# You can get your authtoken from https://dashboard.ngrok.com/get-started/your-authtoken
ngrok.set_auth_token('3FGU25aGBouONGpxd3C8KRU2eHB_4nUeEiJznzM1aKrgbkfBP')

public_url = ngrok.connect(8502)
print(public_url)
# Out:
# NgrokTunnel: "https://throbbing-harbor-dazzler.ngrok-free.dev" -> "http://localhost:8502"

# %%
# Create the directory for the project structure
# !mkdir -p bengaluru-house-price-predictor

# %%
# Move and rename the trained model file to the new directory
# !mv RidgeModel_new.joblib bengaluru-house-price-predictor/model.pkl
print("RidgeModel_new.joblib moved and renamed to bengaluru-house-price-predictor/model.pkl")
# Out:
# RidgeModel_new.joblib moved and renamed to bengaluru-house-price-predictor/model.pkl

# %%
import joblib

# Replace 'ridge_model' with the exact variable name of your trained model
joblib.dump(pipe, 'RidgeModel_new.joblib')
# Out:
# ['RidgeModel_new.joblib']

# %%
# !python -c "import sklearn; print(sklearn.__version__)"
# Out:
# 1.6.1

# %%
# Out:
# NgrokTunnel: "https://throbbing-harbor-dazzler.ngrok-free.dev" -> "http://localhost:8501"
